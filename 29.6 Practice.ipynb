# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/bubble.csv')

# %%
df
# Out:
#     size   iterations    size2
# 0     10           45      100
# 1     20          190      400
# 2     30          435      900
# 3     40          780     1600
# 4     50         1225     2500
# ..   ...          ...      ...
# 95   960       460320   921600
# 96   970       469965   940900
# 97   980       479710   960400
# 98   990       489555   980100
# 99  1000       499500  1000000
#
# [100 rows x 3 columns]

# %%
df['size2'] = df['size'].apply(lambda x: x**2)

# %%
df.head()
# Out:
#    size   iterations  size2
# 0    10           45    100
# 1    20          190    400
# 2    30          435    900
# 3    40          780   1600
# 4    50         1225   2500

# %%
ax = df.plot(x="size", y=" iterations", kind="line")
df.plot(x="size", y="size2", kind="line", ax=ax, color="purple")
# Out:
# <AxesSubplot:xlabel='size'>

# %%
# формула для расчета итерации от n
def sum_iterations(n):
    return sum(x+1 for x in range (0, n-1))

# по сути мы реализовали формулу ниже, это тот алгоритм, по которому мы можем посчитать количество итераций в зависимости
# от n - количества элементов в данных

# %% [markdown]
# ![image.png](attachment:image.png)
